# %% [markdown]
# <a href="https://colab.research.google.com/github/TechyMT/ClassWork/blob/main/DSBDA/Assgn3_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 3.1 Descriptive Statistics - Measures of Central Tendency and variability
# Provide summary statistics (mean, median, minimum, maximum, standard deviation) for a dataset (age, income etc.) with numeric variables grouped by one of the qualitative (categorical) variable. For example, if your categorical variable is age groups and quantitative variable is income, then provide summary statistics of income grouped by the age groups. Create a list that contains a numeric value for each response to the categorical variable.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("/content/nba.csv")

# %%
print(df.shape)
df.head()
# Out:
# (458, 9)
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
df.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Name         1
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64

# %%
df["Salary"].fillna(df["Salary"].mean(), inplace = True)

df.isna().sum()
# Out:
# Name         1
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary       0
# dtype: int64

# %%
mode = df["College"].mode()
df["College"].fillna(mode, inplace= True)

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %%
df["Height"].value_counts()
# Out:
# Height
# 6-9     50
# 6-7     37
# 6-6     37
# 6-8     36
# 6-10    34
# 6-5     30
# 6-11    29
# 6-4     28
# 6-3     27
# 7-0     20
# 6-2     15
# 6-1     12
# 6-0     10
# 5-11     3
# 7-1      3
# 5-9      1
# 7-2      1
# Name: count, dtype: int64

# %%
groups = df.groupby(df["Height"])

# %%
print(groups.get_group('6-11'))
# Out:
#                    Name                    Team  Number Position   Age Height  \
# 24     Chris McCullough           Brooklyn Nets     1.0       PF  21.0   6-11
# 55         Nerlens Noel      Philadelphia 76ers     4.0       PF  22.0   6-11
# 56        Jahlil Okafor      Philadelphia 76ers     8.0        C  20.0   6-11
# 60       Christian Wood      Philadelphia 76ers    35.0       PF  20.0   6-11
# 73       Jason Thompson         Toronto Raptors     1.0       PF  29.0   6-11
# 81         Festus Ezeli   Golden State Warriors    31.0        C  26.0   6-11
# 91         Cole Aldrich    Los Angeles Clippers    45.0        C  27.0   6-11
# 98       DeAndre Jordan    Los Angeles Clippers     6.0        C  27.0   6-11
# 113          Ryan Kelly      Los Angeles Lakers     4.0       PF  25.0   6-11
# 143    DeMarcus Cousins        Sacramento Kings    15.0        C  25.0   6-11
# 162         Joakim Noah           Chicago Bulls    13.0        C  31.0   6-11
# ...

# %%
groups["Salary"].describe()
# Out:
#         count          mean           std         min          25%  \
# Height
# 5-11      3.0  5.891553e+05  7.926627e+05     55722.0    133733.00
# 5-9       1.0  6.912869e+06           NaN   6912869.0   6912869.00
# 6-0      10.0  5.784075e+06  6.337144e+06    947276.0   2437500.00
# 6-1      12.0  5.456567e+06  4.585905e+06    700902.0   1898610.00
# 6-10     34.0  5.111545e+06  5.162012e+06    222888.0   1044792.25
# 6-11     29.0  5.920326e+06  7.067208e+06    245177.0   1140240.00
# 6-2      15.0  2.862862e+06  2.576949e+06    525093.0    947276.00
# 6-3      27.0  5.765194e+06  5.759044e+06    189455.0   1841940.00
# 6-4      28.0  4.358526e+06  5.135309e+06    134215.0   1006902.75
# 6-5      30.0  4.379143e+06  4.235717e+06     55722.0   1159800.00
# 6-6      37.0  2.963790e+06  3.167094e+06    167406.0    947276.00
# 6-7      37.0  3.716167e+06  4.684027e+06    200600.0    981348.00
# 6-8      36.0  5.616665e+06  5.807020e+06     83397.0   1128220.00
# ...

# %%
df["Age"].describe()
# Out:
# count    373.000000
# mean      26.648794
# std        4.250551
# min       19.000000
# 25%       24.000000
# 50%       26.000000
# 75%       29.000000
# max       40.000000
# Name: Age, dtype: float64

# %%
bins = [10,20,30,40]
labels=["10-20", "20-30", "30-40"]
df["AgeGroup"] = pd.cut(df["Age"], bins, labels = labels)


age_groups = df.groupby("AgeGroup")

# %%
age_groups["Salary"].describe()
# Out:
#           count          mean           std       min        25%        50%  \
# AgeGroup
# 10-20      17.0  2.536190e+06  1.523857e+06  525093.0  1733040.0  2239800.0
# 20-30     290.0  4.627182e+06  5.069385e+06   55722.0   986011.0  2494765.0
# 30-40      66.0  5.157263e+06  5.488817e+06  200600.0  1461687.0  3850156.5
#
#                 75%         max
# AgeGroup
# 10-20     2841960.0   5703600.0
# 20-30     6496621.5  20158622.0
# 30-40     5469743.5  22875000.0
